# %%
import requests
import json
from IPython.display import Image, display

API_URL = "https://your-deployment-name.roboflow.cloud"
API_KEY = "HcUxsOH12KCsbKWDuBG3"
MODEL_ID = "ARSHIA/plateDetector/1"   # مثل: "soccer-players-5fuqs/1"

image_path = "test.jpg"

# اگر عکس لوکال داری
with open(image_path, "rb") as f:
    response = requests.post(
        f"{API_URL}/{MODEL_ID}",
        params={"api_key": API_KEY},
        files={"file": f}
    )

# یا اگر URL داری:
# response = requests.get(f"{API_URL}/{MODEL_ID}", params={"api_key": API_KEY, "image": "https://..."})

if response.status_code == 200:
    result = response.json()
    print(result)

    # برای نمایش: معمولاً endpoint /annotate هم داره یا خودت با supervision رسم کن
else:
    print("خطا:", response.text)

# %%
# !python -m pip install --upgrade pip
# Out:
# ...
#   Using cached pip-25.3-py3-none-any.whl.metadata (4.7 kB)
# Using cached pip-25.3-py3-none-any.whl (1.8 MB)
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 25.1.1
#     Uninstalling pip-25.1.1:
#       Successfully uninstalled pip-25.1.1
# ...

# %%
# !pip install inference
# Out:
# ERROR: Ignored the following yanked versions: 0.7.2, 0.7.6, 0.8.0, 0.8.1, 0.8.2, 0.8.4, 0.8.5, 0.8.8, 0.8.9, 0.9.0, 0.9.1, 0.9.2, 0.9.3, 0.9.4, 0.9.5, 0.9.6, 0.9.7rc2, 0.9.7, 0.9.8, 0.9.9rc23, 0.9.9, 0.9.10rc3, 0.9.10, 0.9.11rc1, 0.9.11rc2, 0.9.11, 0.9.12rc1, 0.9.12rc3, 0.9.12, 0.9.13, 0.9.14, 0.9.15rc1, 0.9.15, 0.9.16, 0.9.17
# ...

# %%
# !python --version
# Out:
# Python 3.13.7
